# %% [markdown]
# # Grafik dan Python Scripts
# ## Grafik
# Matplotlib adalah library Python untuk membuat visualisasi data. Library ini
# sangat fleksibel dan dapat digunakan untuk membuat berbagai jenis grafik, seperti grafik
# garis, batang, pie chart, histogram, scatter plot, dan grafik 3D. Library ini menyediakan
# kontrol penuh atas elemen-elemen grafik, seperti sumbu, label, grid, warna, legenda, dan
# gaya garis.

# %% [markdown]
# ### Install Matplotlib

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Jika gagal, perbarui pip
pip install --upgrade pip
# Out:
#   Cell In[2], line 2
#     pip install --upgrade pip
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 0. Mempersiapkan Data yang akan divisualisasikan

# %%
x = [1,2,3]
y = [4,5,6]

# %% [markdown]
# #### 0.1. Import Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1. Membuat Grafik sederhana

# %%
plt.plot(x)
plt.plot(y)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### 2. Menambahkan Judul & Label

# %%
plt.plot(x)
plt.plot(y)
plt.title("Perbandingan X dan Y")
plt.xlabel("Index")
plt.ylabel("Nilai")
plt.show
# Out:
# Text(0, 0.5, 'Nilai')

# %% [markdown]
# #### 3. Memberikan Warna Pada Grafik

# %% [markdown]
# Menggunakan Nama Warna

# %%
plt.plot(x, color="red")
plt.plot(y, color="blue")
plt.title("Perbandingan X dan Y")
plt.xlabel("Index")
plt.ylabel("Nilai")
plt.show
# Out:
# Text(0, 0.5, 'Nilai')

# %% [markdown]
# Menggunakan Kode HEX

# %%
plt.plot(x, color="#0080ff")
plt.plot(y, color="#ff8000")
plt.title("Perbandingan X dan Y")
plt.xlabel("Index")
plt.ylabel("Nilai")
plt.show
# Out:
# Text(0, 0.5, 'Nilai')

# %% [markdown]
# Menggunakan RGB

# %%
plt.plot(x, color=(1,0,0.5))
plt.plot(y, color=(0.5,0,0.5))
plt.title("Perbandingan X dan Y")
plt.xlabel("Index")
plt.ylabel("Nilai")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### 4. Mengatur Gaya Garis

# %%
plt.plot(x, color=(1,0,0.5), linestyle='--')
plt.plot(y, color=(0.5,0,0.5), linestyle='-.')
plt.title("Perbandingan X dan Y")
plt.xlabel("Index")
plt.ylabel("Nilai")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### 5. Menambahkan Marker

# %%
plt.plot(x, color=(1,0,0.5), linestyle='--', marker='s')
plt.plot(y, color=(0.5,0,0.5), linestyle='-.', marker='v')
plt.title("Perbandingan X dan Y")
plt.xlabel("Index")
plt.ylabel("Nilai")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### 6. Menggabungkan Gaya, warna, dan Marker

# %%
plt.plot(x,"r--o")
plt.plot(y, "s-.b")
plt.title("Perbandingan X dan Y")
plt.xlabel("Index")
plt.ylabel("Nilai")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### 7. Mengatur Lebar dan Ukuran

# %% [markdown]
# #### 8. Menampilkan Grafik Kurva y=x^3 dengan rentang x=-3 hingga x=3

# %% [markdown]
# ##### 8.1 Import numpy

# %%
import numpy as np

# %% [markdown]
# ##### 8.2 Memuat data x dan y

# %%
x = np.arange(-3, 3.1, 0.5)
y = x**3

# %% [markdown]
# ##### 8.3 Visualisasi

# %%
plt.plot(x,y, "b--s")
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### 9. Menampilkan Beberapa Kurva dalam Satu Grafik

# %% [markdown]
# ##### 9.1 Data X untuk Grafik

# %%
x = np.linspace(0, 500, 100)
print(x)
# Out:
# [  0.           5.05050505  10.1010101   15.15151515  20.2020202
#   25.25252525  30.3030303   35.35353535  40.4040404   45.45454545
#   50.50505051  55.55555556  60.60606061  65.65656566  70.70707071
#   75.75757576  80.80808081  85.85858586  90.90909091  95.95959596
#  101.01010101 106.06060606 111.11111111 116.16161616 121.21212121
#  126.26262626 131.31313131 136.36363636 141.41414141 146.46464646
#  151.51515152 156.56565657 161.61616162 166.66666667 171.71717172
#  176.76767677 181.81818182 186.86868687 191.91919192 196.96969697
#  202.02020202 207.07070707 212.12121212 217.17171717 222.22222222
#  227.27272727 232.32323232 237.37373737 242.42424242 247.47474747
#  252.52525253 257.57575758 262.62626263 267.67676768 272.72727273
#  277.77777778 282.82828283 287.87878788 292.92929293 297.97979798
#  303.03030303 308.08080808 313.13131313 318.18181818 323.23232323
#  328.28282828 333.33333333 338.38383838 343.43434343 348.48484848
# ...

# %% [markdown]
# ##### 9.2 Membuat Beberapa Kurva

# %%
y1 = x
y2 = x**2

# %% [markdown]
# ##### 9.3 Plot semua kurva

# %%
plt.plot(x, y1)
plt.plot(x, y2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Python Script

# %% [markdown]
# ### 2. Menggunakan fungsi dalam script

# %% [markdown]
# #### 2.1 Membuat Fungsi

# %%
def hitungPersegiPanjang(panjang, lebar):
    luas = panjang*lebar
    keliling = 2*panjang + 2*lebar
    return luas, keliling

# %% [markdown]
# #### 2.2 Memanggil Fungsi

# %%
luas, keliling = hitungPersegiPanjang(10, 4)
print(luas, keliling)
# Out:
# 40 28

# %% [markdown]
# ### 3. Menggunakan Input dari Pengguna

# %% [markdown]
# #### 3.1 Membuat fungsi hitung lingkaran

# %%
def hitungLingkaran(r):
    luasLingkaran = 22/7*r**2
    return luasLingkaran

# %% [markdown]
# #### 3.2 Memanggil fungsi lingkaran dengan input user

# %%
r = int(input("Masukkan Ruji Lingkaran"))
print(hitungLingkaran(r))
# Out:
# 154.0

# %% [markdown]
# # TUGAS PRAKTIKUM

# %% [markdown]
# Buat grafik bar untuk menampilkan jumlah penjualan barang selama 5 bulan dengan
# data berikut:
#
# • Bulan: Januari, Februari, Maret, April, Mei
#
# • Penjualan: 150, 200, 180, 220, 170
#
# Berikan judul grafik, label sumbu X (Bulan), dan label sumbu Y (Jumlah Penjualan)

# %%
import numpy as np
import matplotlib.pyplot as plt

#nomor 1
penjualan = np.array([150, 200, 180, 220, 170])
bulan = ["Januari", "Februari", "Maret", "April", "Mei"]
plt.bar(bulan, penjualan)
plt.title("Penjualan Barang Selama 5 Bulan")
plt.xlabel("Bulan")
plt.ylabel("Jumlah Penjualan")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Dari data yang sama, buatlah diagram pie untuk menunjukkan persentase kontribusi
# penjualan tiap bulan. Pastikan setiap bagian memiliki label bulan.

# %%
plt.pie(penjualan, labels= ["Januari", "Februari", "Maret", "April", "Mei"], autopct="%1.1f%%")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Buat grafik scatter plot untuk menampilkan hubungan antara usia dan penghasilan
# seseorang berdasarkan data berikut:
#
# • Usia: [20, 25, 30, 35, 40, 45, 50]
#
# • Penghasilan: [2000, 3200, 4500, 5500, 6100, 5800, 5000]
#
# Tambahkan:
#
# • Warna marker hijau ('g') dan bentuk lingkaran ('o').
#
# • Judul grafik "Hubungan Usia dan Penghasilan".
#
# • Label sumbu X dengan "Usia (Tahun)" dan sumbu Y dengan "Penghasilan
# (Ribu USD)".

# %%
usia = [20, 25, 30, 35, 40, 45, 50]
penghasilan = [2000, 3200, 4500, 5500, 6100, 5800, 5000]

plt.scatter(usia, penghasilan, marker='o', color='g')
plt.title("Hubungan Usia dan Penghasilan")
plt.xlabel("Usia (Tahun)")
plt.ylabel("Penghasilan (Ribu USD)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Buatlah suatu script python untuk menghitung volume dan luas permukaan balok
# dengan spesifikasi:
#
# masukan fungsi : panjang, lebar, dan tinggi balok
#
# keluaran fungsi : volume, dan luas permukaan balok.
#
# Beri nama fungsi ini dengan hitung_balok.py

# %%
def hitung_balok(panjang, lebar, tinggi):
    volume = panjang * lebar * tinggi
    luasPermukaan = panjang*4 + lebar*4 + tinggi*4
    return volume, luasPermukaan


panjang = int(input("Masukkan Panjang Balok : "))
lebar = int(input("Masukkan lebar Balok : "))
tinggi = int(input("Masukkan tinggi Balok : "))
volume, luasPermukaan = hitung_balok(panjang, lebar, tinggi)
print("Volume balok adalah : ", volume)
print("Luas Permukaan Balok adalah : ", luasPermukaan)
# Out:
# Volume balok adalah :  1000
# Luas Permukaan Balok adalah :  120

# %% [markdown]
# Buatlah sebuah fungsi untuk menghitung jumlah hari di antara dua tanggal. Spesifikasi
# dari fungsi tersebut ialah:
#
# masukan : tanggal, bulan, dan tahun awal, serta tanggal, bulan, dan tahun akhir.
#
# keluaran : jumlah hari di antara dua tanggal tersebut.
#
# Beri nama fungsi ini dengan hitung_hari.py.
#
# Misalkan akan menghitung jumlah hari antara 2 Januari 2004 hingga 5 November
# 2006, maka tulis:
#
# jml_hari = hitung_hari(2,1,2004,5,11,2006)
#
# jml_hari = 1038

# %%
from datetime import datetime
def hitung_hari(tanggal1, bulan1, tahun1, tanggal2, bulan2, tahun2):
    hari1 = datetime(tahun1, bulan1, tanggal1)
    hari2 = datetime(tahun2, bulan2, tanggal2)
    selisih = hari1 - hari2
    return abs(selisih.days)

jml_hari = hitung_hari(2,1,2004,5,11,2006)
print(jml_hari)
# Out:
# 1038
